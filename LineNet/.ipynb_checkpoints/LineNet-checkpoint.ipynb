# %%
from mindspore import context

context.set_context(mode=context.GRAPH_MODE, device_target="CPU")

# %% [markdown]
# ### 生成数据

# %%
import numpy as np


def get_data(num, w=2.0, b=3.0):
    for i in range(num):
        x = np.random.uniform(-10.0, 10.0)
        noise = np.random.normal(0, 1)
        y = w * x + b + noise
        yield np.array([x]).astype(np.float32),np.array([y]).astype(np.float32)

# %% [markdown]
# ### yield,zip,zip(*)是理解代码的关键

# %%
import matplotlib.pyplot as plt

eval_data = list(get_data(50))
x_target_label = np.array([-10, 10, 0.1])
y_target_label = x_target_label * 2 + 3
# zip()是压缩，与yield类似，zip(*)是解压缩
x_eval_label, y_eval_label = zip(*eval_data)

plt.scatter(x_eval_label, y_eval_label, color="red", s=5)
plt.plot(x_target_label, y_target_label, color="green")
plt.title("Eval data")
plt.show()

# %% [markdown]
# ### 创建数据集

# %%
from mindspore import dataset as ds

def create_dataset(num_data, batch_size=16, repeat_size=1):
    input_data = ds.GeneratorDataset(list(get_data(num_data)), column_names=['data', 'label'])
    input_data = input_data.batch(batch_size)
    input_data = input_data.repeat(repeat_size)
    return input_data

# %%
data_number = 1600
batch_number = 16
repeat_number = 2

ds_train = create_dataset(data_number, batch_size=batch_number, repeat_size=repeat_number)
print("The dataset size of ds_train:", ds_train.get_dataset_size())
dict_datasets = next(ds_train.create_dict_iterator())

print(dict_datasets.keys())
print("The x label value shape:", dict_datasets["data"].shape)
print("The y label value shape:", dict_datasets["label"].shape)
# Out:
# [WARNING] ME(3656:10852,MainProcess):2022-11-11-20:43:42.626.6 [mindspore\dataset\engine\datasets_user_defined.py:657] Python multiprocessing is not supported on Windows platform.
# The dataset size of ds_train: 200
# dict_keys(['data', 'label'])
# The x label value shape: (16, 1)
# The y label value shape: (16, 1)

# %% [markdown]
# ### 定义线性网络

# %%
from mindspore.common.initializer import Normal
from mindspore import nn

class LinearNet(nn.Cell):
    def __init__(self):
        super(LinearNet, self).__init__()
        self.fc = nn.Dense(1, 1, Normal(0.02), Normal(0.02))

    def construct(self, x):
        x = self.fc(x)
        return x

# %%
net = LinearNet()
model_params = net.trainable_params()
for param in model_params:
    print(param, param.asnumpy())
# Out:
# Parameter (name=fc.weight, shape=(1, 1), dtype=Float32, requires_grad=True) [[0.00861623]]
# Parameter (name=fc.bias, shape=(1,), dtype=Float32, requires_grad=True) [-0.0009024]

# %%
from mindspore import Tensor

x_model_label = np.array([-10, 10, 0.1])
y_model_label = (x_model_label * Tensor(model_params[0]).asnumpy()[0][0] +
                 Tensor(model_params[1]).asnumpy()[0])

plt.axis([-10, 10, -20, 25])
plt.scatter(x_eval_label, y_eval_label, color="red", s=5)
plt.plot(x_model_label, y_model_label, color="blue")
plt.plot(x_target_label, y_target_label, color="green")
plt.show()

# %%
net=LinearNet()
net_loss=nn.loss.MSELoss()
opt=nn.Momentum(net.trainable_params(),learning_rate=0.005,momentum=0.9)

# %%
print(net)
# Out:
# LinearNet<
#   (fc): Dense<input_channels=1, output_channels=1, has_bias=True>
#   >

# %%
from mindspore import Model
model=Model(network=net,loss_fn=net_loss,optimizer=opt)

# %%
import matplotlib.pyplot as plt
import time

def plot_model_and_datasets(net, eval_data):
    weight = net.trainable_params()[0]
    bias = net.trainable_params()[1]
    x = np.arange(-10, 10, 0.1)
#     Tensor(weight).asnumpy()[0][0]为权重参数，Tensor(bias).asnumpy()[0]为偏置
    y = x * Tensor(weight).asnumpy()[0][0] + Tensor(bias).asnumpy()[0]
    x1, y1 = zip(*eval_data)
    x_target = x
    y_target = x_target * 2 + 3

    plt.axis([-11, 11, -20, 25])
    plt.scatter(x1, y1, color="red", s=5)
    plt.plot(x, y, color="blue")
    plt.plot(x_target, y_target, color="green")
    plt.show()
    time.sleep(0.2)

# %%
from IPython import display
from mindspore.train.callback import Callback

class ImageShowCallback(Callback):
    def __init__(self, net, eval_data):
        self.net = net
        self.eval_data = eval_data

    def step_end(self, run_context):
        plot_model_and_datasets(self.net, self.eval_data)
        display.clear_output(wait=True)

# %%
epoch = 1
# callback机制动态查看拟合效果
imageshow_cb = ImageShowCallback(net, eval_data)
model.train(epoch, ds_train, callbacks=[imageshow_cb], dataset_sink_mode=False)

plot_model_and_datasets(net, eval_data)
for net_param in net.trainable_params():
    print(net_param, net_param.asnumpy())
# Out:
# Parameter (name=fc.weight, shape=(1, 1), dtype=Float32, requires_grad=True) [[2.02619]]
# Parameter (name=fc.bias, shape=(1,), dtype=Float32, requires_grad=True) [3.0347326]

# %%
x_eval_label
# Out:
# (array([-4.03355], dtype=float32),
#  array([6.73164], dtype=float32),
#  array([5.94227], dtype=float32),
#  array([6.2498274], dtype=float32),
#  array([-4.0624876], dtype=float32),
#  array([-0.5748978], dtype=float32),
#  array([-2.5320425], dtype=float32),
#  array([2.5872896], dtype=float32),
#  array([-6.9619513], dtype=float32),
#  array([-9.961709], dtype=float32),
#  array([8.132913], dtype=float32),
#  array([-1.8585281], dtype=float32),
#  array([1.982638], dtype=float32),
#  array([3.4874537], dtype=float32),
#  array([2.4518454], dtype=float32),
#  array([-6.6159067], dtype=float32),
#  array([7.336422], dtype=float32),
#  array([7.1179967], dtype=float32),
#  array([-1.5033709], dtype=float32),
#  array([7.8103857], dtype=float32),
#  array([6.8108416], dtype=float32),
#  array([6.374146], dtype=float32),
#  array([-1.0304693], dtype=float32),
#  array([1.8059592], dtype=float32),
#  array([7.8182306], dtype=float32),
#  array([-5.862148], dtype=float32),
#  array([-8.142563], dtype=float32),
#  array([-6.4311824], dtype=float32),
#  array([-4.8339076], dtype=float32),
#  array([7.756222], dtype=float32),
#  array([-9.730273], dtype=float32),
#  array([7.484998], dtype=float32),
#  array([7.031443], dtype=float32),
#  array([-8.247119], dtype=float32),
#  array([-8.896868], dtype=float32),
#  array([0.2475735], dtype=float32),
#  array([-4.819594], dtype=float32),
#  array([5.49466], dtype=float32),
#  array([8.660188], dtype=float32),
#  array([4.732148], dtype=float32),
#  array([5.5516124], dtype=float32),
#  array([-0.51429635], dtype=float32),
#  array([9.378749], dtype=float32),
#  array([-1.8688333], dtype=float32),
#  array([-8.674352], dtype=float32),
#  array([1.44394], dtype=float32),
#  array([-7.552086], dtype=float32),
#  array([-4.050153], dtype=float32),
#  array([-0.19077282], dtype=float32),
#  array([9.398508], dtype=float32))
